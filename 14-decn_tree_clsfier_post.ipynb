# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris

# %%
data = load_iris()
df = pd.DataFrame(data.data,columns=data.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.shape
# Out:
# (150, 4)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
x = df.iloc[:,:-1]
y = data.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
regressor = DecisionTreeClassifier(ccp_alpha=0.01)     # ccp_alpha : It controls how much the decision tree gets pruned after it's fully built.

# %%
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01)

# %%
from sklearn import tree
plt.Figure(figsize=(15,10))
tree.plot_tree(regressor,filled=True)
# Out:
# [Text(0.3333333333333333, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.666\nsamples = 112\nvalue = [35, 39, 38]'),
#  Text(0.16666666666666666, 0.75, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.25, 0.8333333333333333, 'True  '),
#  Text(0.5, 0.75, 'x[2] <= 4.75\ngini = 0.5\nsamples = 77\nvalue = [0.0, 39.0, 38.0]'),
#  Text(0.41666666666666663, 0.8333333333333333, '  False'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'x[2] <= 5.05\ngini = 0.21\nsamples = 42\nvalue = [0, 5, 37]'),
#  Text(0.5, 0.4166666666666667, 'x[1] <= 3.05\ngini = 0.48\nsamples = 10\nvalue = [0, 4, 6]'),
#  Text(0.3333333333333333, 0.25, 'x[0] <= 6.25\ngini = 0.375\nsamples = 8\nvalue = [0, 2, 6]'),
#  Text(0.16666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.6666666666666666, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8333333333333334, 0.4166666666666667, 'gini = 0.061\nsamples = 32\nvalue = [0, 1, 31]')]

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9736842105263158

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.92      1.00      0.96        11
#            2       1.00      0.92      0.96        12
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38
